# %%
class Student:
    def __init__(self,name,roll_num,marks):
        self.name = name
        self.roll_num = roll_num
        self.marks = marks

# %%
Student1 = Student('Sohail',12345,500)

# %%
Student1.marks
# Out:
# 500
